# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from skimage import data
from skimage.feature import blob_dog,blob_log,blob_doh
from math import sqrt
from skimage.color import rgb2gray
import glob
from skimage.io import imread

#fetching image

example_file = glob.glob("C:\machine_ws\stars.jpg")[0]
im = imread(example_file, as_gray=True)
plt.imshow(im)
plt.show()

# %%
# -*- coding: utf-8 -*-
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from skimage import data
from skimage.feature import blob_dog,blob_log,blob_doh
from math import sqrt
from skimage.color import rgb2gray
import glob
from skimage.io import imread

#fetching image

example_file = glob.glob("C:\machine_ws\star0.jpg")[0]
im = imread(example_file, as_gray=True)
plt.imshow(im)
plt.show()

#count number of stars
blobs_log = blob_log(im, max_sigma=30,num_sigma = 10,threshold = .01)
blobs_log[:, 2] = blobs_log[:, 2] * sqrt(2)
stars = len(blobs_log)
print('Number of stars:',stars)
# Out:
# Number of stars: 2072

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(im)
for blob in blobs_log:
    y,x,r =blob
    c= plt.Circle((x,y), r+5,color = 'lime',linewidth=2, fill = False)
    ax.add_patch(c)

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Aug  7 14:49:28 2019

@author: LENOVO
"""
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from skimage import data
from skimage.feature import blob_dog,blob_log,blob_doh
from math import sqrt
from skimage.color import rgb2gray
import glob
from skimage.io import imread

#fetching image

example_file = glob.glob("C:\machine_ws\star3.jpg")[0]
im = imread(example_file, as_gray=True)
plt.imshow(im)
plt.show()

#count number of stars
blobs_log = blob_log(im, max_sigma=30,num_sigma = 10,threshold = .1)
blobs_log[:, 2] = blobs_log[:, 2] * sqrt(2)
stars = len(blobs_log)
print('Number of stars:',stars)


#actual count

fig, ax = plt.subplots(1,1)
plt.imshow(im)
for blob in blobs_log:
    y,x,r =blob
    c= plt.Circle((x,y), r+5,color = 'white',linewidth=2, fill = False)
    ax.add_patch(c)
# Out:
# Number of stars: 325
